# %% [markdown]
#  ### DS7337 NLP - HW 5
#  ### Neil Benson

# %% [markdown]
#  <u>**HW 5:**</u>
#
#  1.	Compile a list of static links (permalinks) to individual user movie reviews from one particular website.
#        This will be your working dataset for this assignment, as well as for assignments 7 and 8, which together will make up your semester project.
#
#        a.	It does not matter if you use a crawler or if you manually collect the links, but you will need at least 100 movie review links.
#            Note that, as of this writing, the robots.txt file of IMDB.com allows the crawling of user reviews.
#
#        b.	Each link should be to a web page that has only one user review of only one movie, e.g., the user review permalinks on the IMDB site.
#
#        c.	Choose reviews of movies that are all in the same genre, e.g., sci-fi, mystery, romance, superhero, etc.
#
#        d.	Make sure your collection includes reviews of several movies in your chosen genre and that it includes a mix of negative and positive reviews.
#
#
#  2.	Extract noun phrase (NP) chunks from your reviews using the following procedure:
#
#        a.	In Python, use BeautifulSoup to grab the main review text from each link.
#
#        b.	Next run each review text through a tokenizer, and then try to NP-chunk it with a shallow parser.
#
#        c.	You probably will have too many unknown words, owing to proper names of characters, actors, and so on that are not in your working dictionary. Make sure the main names that are relevant to the movies in your collection of reviews are added to the working lexicon, and then run the NP chunker again.
#
#
#  3.	Output all the chunks in a single list for each review, and submit that output for this assignment.
#        Also submit a brief written summary of what you did (describe your selection of genre, your source of reviews,
#        how many you collected, and by what means).

# %%
# imports
import operator
import random
import string
import pprint
from nltk.tokenize import TweetTokenizer
import spacy
from spacy.util import minibatch, compounding
from spacy.training import Example
from spacy.matcher import PhraseMatcher
from requests import get
from bs4 import BeautifulSoup
import warnings

# %%
# isable output warnings
warnings.filterwarnings("ignore")

# %%
# %%javascript
# // disable output scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# # Extract Top 10 Thriller Movies from IMDB
# the following functions:
# * Use BeautifulSoup
# * Select genre - this was abitrary
# * Set genre link
# * Get list of movies (10) from genre page
# * Get each movie's respective unique URL
# * Get a list of reviews, cast, and characters from each movie page
# * Get each review's respective unique URL
# * Filter out reviews > 7 or < 4
# * Combine movie title, review title, and review content together
# * Tokenize reviews
# * Chunk the reviews into NP using spaCy

# %%
def get_soup(url, headers):
    request = get(url, headers)
    soup = BeautifulSoup(request.content, "html.parser")
    return soup


def get_movies_list(url, headers):
    # gets the list of movies
    movies_soup = get_soup(url, headers).find(class_="lister-list")

    # gets all individual movies
    movies = movies_soup.find_all(class_="lister-item mode-advanced")

    # limiting to the top 10 movies
    return movies[0:10]


def get_movie_links(base_url, movies):
    return [f"{base_url}{movie.find('a').get('href')}" for movie in movies]


def get_movie_titles(movies):
    return [movie.find("img", alt=True).get("alt") for movie in movies]


def get_movie_cast_characters(movie_links, headers):
    cast_character_soup_list = [
        get_soup(link, headers).find(class_="cast_list") for link in movie_links
    ]

    cast_soup = [
        table.find_all(class_="primary_photo") for table in cast_character_soup_list
    ]

    characters_soup = [
        table.find_all(class_="character") for table in cast_character_soup_list
    ]

    cast_names = [
        cast_member.select('[href^="/name"]')[0].find("img", alt=True).get("alt")
        for movie in cast_soup
        for cast_member in movie
    ]

    character_names = [
        str(character.select('[href^="/title"]')[0].contents[0])
        for movie in characters_soup
        for character in movie
        if len(character.select('[href^="/title"]')) > 0
    ]

    return cast_names, character_names


def get_user_review_rating(review):
    if review.find(class_="ipl-ratings-bar"):
        # extract rating if class exists
        return float(review.find("span", attrs={"class": None}).contents[0])
    # default rating to '-1' if no rating exist
    else:
        return -1


def filter_reviews_list(reviews_list):
    filtered_reviews = [
        [
            review
            for review in movie
            # positive reviews
            if get_user_review_rating(review) > 7
            or (
                # negative reviews
                get_user_review_rating(review) < 4
                and get_user_review_rating(review) > 0
            )
        ]
        for movie in reviews_list
    ]

    return filtered_reviews


def get_reviews_list(movie_links, headers):
    reviews_list = [
        get_soup(f"{link}reviews", headers).find_all(class_="review-container")
        for link in movie_links
    ]

    return filter_reviews_list(reviews_list)


def get_user_review_urls(reviews_list, base_url):
    user_review_urls = [
        [
            f"{base_url}{review.find('a', attrs={'class': 'title'})['href']}"
            for review in movie
        ]
        for movie in reviews_list
    ]

    return user_review_urls


def get_user_review_titles(reviews_list):
    user_review_titles = [
        [
            f"{review.find('a', attrs={'class': 'title'}).contents[0]}"
            for review in movie
        ]
        for movie in reviews_list
    ]

    return user_review_titles


def get_user_review_content(user_review_urls, headers):
    user_review_content_list = [
        [
            get_soup(link, headers).find(class_="text show-more__control").contents[0]
            for link in movie
        ]
        for movie in user_review_urls
    ]

    return user_review_content_list


def get_zipped_reviews(user_review_titles, user_review_content, user_review_urls):

    zipped_reviews = [
        list(zip(movie[0], movie[1], movie[2]))
        for movie in list(
            zip(user_review_titles, user_review_content, user_review_urls)
        )
    ]

    return zipped_reviews


def movies_with_user_reviews(zipped_reviews, movie_names):
    movies_with_user_reviews = {
        "movies": [
            {
                "id": idx,
                "title": movie_names[idx],
                "reviews": [
                    {
                        "id": rvw_idx,
                        "review_title": movie_review[0],
                        "content": movie_review[1],
                        "url": movie_review[2],
                    }
                    for rvw_idx, movie_review in enumerate(movie_reviews)
                ],
            }
            for idx, movie_reviews in enumerate(zipped_reviews)
        ]
    }

    return movies_with_user_reviews


def tokenizer(review, tknzr):
    # tokenizes the review and removes punctuation

    tokens = tknzr.tokenize(review)
    remove_punctuation = [i for i in tokens if i not in list(string.punctuation)]

    return " ".join(remove_punctuation)


def get_np_chunks(review_tokens, nlp):
    doc = nlp(review_tokens)
    return doc.noun_chunks

# %% [markdown]
# ### Local browser headers to pass along in the GET requests

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:89.0) Gecko/20100101 Firefox/89.0",
}

# %% [markdown]
# ### Set the thriller movies URL

# %%
thrillers_url = "https://www.imdb.com/search/title/?genres=thriller"
base_url = "https://www.imdb.com"

# %% [markdown]
# ### Get a list of movies

# %%
movies = get_movies_list(thrillers_url, headers)

# %% [markdown]
# ### Get each movie's page unique URL

# %%
movie_links = get_movie_links(base_url, movies)
movie_links
# Out:
# ['https://www.imdb.com/title/tt5834204/',
#  'https://www.imdb.com/title/tt8421350/',
#  'https://www.imdb.com/title/tt6654210/',
#  'https://www.imdb.com/title/tt8332922/',
#  'https://www.imdb.com/title/tt7069210/',
#  'https://www.imdb.com/title/tt10418662/',
#  'https://www.imdb.com/title/tt5433138/',
#  'https://www.imdb.com/title/tt2741602/',
#  'https://www.imdb.com/title/tt5028002/',
#  'https://www.imdb.com/title/tt8385148/']

# %% [markdown]
# ### Get a list of the movie titles, cast, and characters
#  The cast and characters will be used to later update the NER lists

# %%
movie_names = get_movie_titles(movies)
movie_names
# Out:
# ["The Handmaid's Tale",
#  'Manifest',
#  'Infinite',
#  'A Quiet Place Part II',
#  'The Conjuring: The Devil Made Me Do It',
#  'Awake',
#  'F9: The Fast Saga',
#  'The Blacklist',
#  'StartUp',
#  "The Hitman's Wife's Bodyguard"]

# %% [markdown]
# ### Extract all the top 25 review objects from IMDB

# %%
reviews_list = get_reviews_list(movie_links, headers)

# %% [markdown]
# ### Extract the urls from filtered positive (>7) and negative reviews (<4)

# %%
user_review_urls = get_user_review_urls(reviews_list, base_url)

print(f"Total number of reviews extracted: {sum(len(i) for i in user_review_urls)}")
# Out:
# Total number of reviews extracted: 146

# %% [markdown]
# ### Extract the review title and content (text) for each of the filtered reviews

# %%
user_review_titles = get_user_review_titles(reviews_list)
user_review_content = get_user_review_content(user_review_urls, headers)

# %% [markdown]
# ### Combining it all back together

# %%
zipped_reviews = get_zipped_reviews(
    user_review_titles, user_review_content, user_review_urls
)

movies_with_reviews = movies_with_user_reviews(zipped_reviews, movie_names)

# %% [markdown]
# ### Reviewing the data pulled from IMDB

# %%
# movies reviewed
pprint.pprint([movie["title"] for movie in movies_with_reviews["movies"]])
print(f"\n")

# a few movies with their respective reviews
pprint.pprint(
    [
        (movie["title"], movie["reviews"][0:2])
        for movie in movies_with_reviews["movies"][0:3]
    ],
    sort_dicts=False,
)
# Out:
# ["The Handmaid's Tale",
#  'Manifest',
#  'Infinite',
#  'A Quiet Place Part II',
#  'The Conjuring: The Devil Made Me Do It',
#  'Awake',
#  'F9: The Fast Saga',
#  'The Blacklist',
#  'StartUp',
#  "The Hitman's Wife's Bodyguard"]
#
#
# [("The Handmaid's Tale",
#   [{'id': 0,
#     'review_title': ' You think you have seen horror films?\n',
#     'content': "If I may start 'off-topic' for a moment. I am male, mid "
#                'sixties, and have watched, like many others, all the great '
#                '(and not-so-great) horror films. After watching the ten '
#                "episodes of 'The Handmaid's Tale' I can safely say that THIS "
#                'is a real horror story. It makes the entire horror genre seem '
#                'like cotton candy. After each episode I find myself shaking, '
#                "often with tears in my eyes. I'm not going to talk about the "
#                'story. I am going to tell you that the acting is beyond '
#                'reproach. In almost every movie, every TV series, there are at '
#                "least one or two characters that don't fit or are poorly "
#                'portrayed. Not so here. I simply cannot find fault with the '
#                'performances of the entire cast. Stellar! The sets, the '
#                'direction, the camera work, the intensity all fit together '
#                'seamlessly. This is a story of a good world...gone very wrong. '
#                'This is a story about faith, twisted by evil intent, then '
#                'thrust upon the common people. For me it is truly horrifying. '
#                "I'm sorry I can't find better words to describe how this show "
#                'affects me. I will say this: My daughter is currently '
#                'attending university in the U.S. and I can tell you I fear for '
#                'her safety every hour of every day. Not because this story is '
#                'happening now...but because it is so close.',
#     'url': 'https://www.imdb.com/review/rw3731386/'},
#    {'id': 1,
#     'review_title': ' It has been said already, but I must agree: A MUST '
#                     'WATCH\n',
#     'content': "I've never written a review in my life. After seeing this and "
#                'then looking for more information about it, I came across IMDb '
#                'and instead of finding intelligent reviews from intelligent '
#                'people, I find a few that scream of ignorance. ',
#     'url': 'https://www.imdb.com/review/rw3696544/'}]),
#  ('Manifest',
#   [{'id': 0,
#     'review_title': ' Please make me stop!\n',
#     'content': 'OMG! I expected a lot more from Bob Zemeckis, but I guess you '
#                "can't be a winner all the time? The worst part for me is the "
#                'acting, pretty much across-the-board except for a scant few! '
#                'The kid who plays Cal Stone, is clearly dead inside, but for '
#                'me the worst is his dad Ben, who obviously subscribes to the '
#                'Joey Tribbiani School of "smell the fart acting"! I don\'t '
#                'know how many more of his scrunched-up expressions I can take? '
#                'It started out a good premise, now I nearly cringe to watch '
#                'it!',
#     'url': 'https://www.imdb.com/review/rw5574376/'},
#    {'id': 1,
#     'review_title': ' Great premise wasted with awful writing\n',
#     'content': 'I can clearly see it. Someone goes "Hey, I had an interesting '
#                'idea for a tv show. About two hundred people board on a plane '
#                'and when they land, 5 years have passed, while for them only a '
#                'few hours. Sounds good, right?". So they pitch the idea to a '
#                'network, it gets picked and handed to a bunch of freshmen in '
#                'writing school to develop it. I mean, seriously. What in the '
#                'world is this? How does anyone in their right mind thinks the '
#                "viewers are gonna buy such lazy writing? I'm honestly baffled "
#                'that this show is scored at a 7.2 right now. It must be some '
#                'sort of manipulation by the network to fool the unwarned. '
#                'Please, do not spend your time on this. This is the kind of '
#                "show that treats the viewer like a brainless moron and doesn't "
#                'even feel sorry about it.',
#     'url': 'https://www.imdb.com/review/rw5168446/'}]),
#  ('Infinite',
#   [{'id': 0,
#     'review_title': ' The Matrix made by the Kardashians\n',
#     'content': 'Out of context and misunderstood ideas chopped from the '
#                'eastern philosophy and patched together in utterly ridiculous '
#                'and boring mess. It\'s a shallow people\'s "deep" movie.',
#     'url': 'https://www.imdb.com/review/rw7021145/'},
#    {'id': 1,
#     'review_title': ' The Matrix meets Dumb and Dumber\n',
#     'content': 'Some individuals on Earth are able to remember their previous '
#                "lives. Among them there's a group of people that is tired of "
#                'their consciousness jumping from one body to the other, who '
#                'decides to end all life on the planet.',
#     'url': 'https://www.imdb.com/review/rw7056541/'}])]

# %% [markdown]
# ### Using nltk to tokenize each review, and spaCy to np chunk the tokens

# %%
nlp = spacy.load("en_core_web_sm")
ner = nlp.get_pipe("ner")
matcher = PhraseMatcher(nlp.vocab)
tknzr = TweetTokenizer()

for movie in movies_with_reviews["movies"]:
    for review in movie["reviews"]:
        # word tokenizingn using nltk
        review["review_tokens"] = tokenizer(
            review["review_title"] + review["content"], tknzr
        )

        # noun phrase chunking using spaCy
        review["review_chunks"] = [
            chunk.text for chunk in get_np_chunks(review["review_tokens"], nlp)
        ]

# %% [markdown]
# ### Get cast and character names for NER update
#  This builds a list of cast and characters. We will later add cast,

# %%
cast_names, character_names = get_movie_cast_characters(movie_links, headers)

# sample cast names for NER additions
cast_names[0:10]
# Out:
# ['June Osborne',
#  'Serena Joy Waterford',
#  'Fred Waterford',
#  'Aunt Lydia Clements',
#  'Janine Lindo',
#  'Rita Blue',
#  'Nick Blaine',
#  'Luke Bankole',
#  'Moira Strand',
#  'Alma']

# %% [markdown]
# ### Train the new NER bc spaCy uses a statistical method to identify named entities
#  By adding new named entities to the vocab/lexicon from the corpus of reviews, we hope to see updated NER

# %% [markdown]
#  The following functions
#    * add phrases/phrase matches to the corpus
#    * offset phrase match from word to character for each review
#    * check the phrase matcher has overlapped any entities, and resolve if so
#    * format each review using spaCy API, including annotations for named entitities
#    * train the NER on the corpus with the formatted reviews

# %%
def set_entity_ner(entity_list, matcher, nlp):
    for i in entity_list[0]:
        matcher.add(entity_list[1], None, nlp.make_doc(i))
    return


def offsetter(lbl, doc, matchitem):
    # offsets word location in text with corresponding letter(s) location
    subdoc = doc[matchitem[1] : matchitem[2]]

    if matchitem[1] == 0:
        string_first = str(subdoc)
        o_one = matchitem[1]

    else:
        string_first = str(doc[0 : matchitem[1]])

        if string_first[-1] == '"' or string_first[-1] == "'":
            o_one = len(string_first)
        else:
            o_one = len(string_first) + 1

    o_two = o_one + len(str(subdoc))
    return (o_one, o_two, lbl)


def match_overlap(matches):
    # before training the model, sometimes spaCy creates overlapping entitities of the same entity
    # this aims to resolve the overlap by creating a single entitity
    # example: "Noah Jupe" was being tagged as "Noah" and "Noah Jupe"; this returns the latter.

    sorted_matches = sorted(matches, key=operator.itemgetter(1, 2))
    match_ranges = [(match[0], range(match[1], match[2])) for match in sorted_matches]
    indeces_to_remove = set()
    new_matches = []

    for index, elem in enumerate(match_ranges):
        if index < (len(match_ranges) - 1):
            this_elem = set(elem[1])
            next_elem = match_ranges[index + 1][1]
            if intersect := this_elem.intersection(next_elem):
                new_matches.append((elem[0], elem[1][0], next_elem[-1] + 1))
                indeces_to_remove.add(index)
                indeces_to_remove.add(index + 1)

    if not indeces_to_remove:
        return sorted_matches

    sorted_matches_dict = {index: value for index, value in enumerate(sorted_matches)}

    for index in indeces_to_remove:
        sorted_matches_dict.pop(index, None)

    sorted_matches = list(sorted_matches_dict.values())
    sorted_matches = sorted(sorted_matches + new_matches, key=operator.itemgetter(1, 2))
    sorted_matches = match_overlap(sorted_matches)

    return sorted_matches


def setup_entity_training_data(sample_data, matcher, nlp):
    # format the ner training data using spaCy api (Example class)
    ner_train_data = []
    for data in sample_data:
        sample_nlp = nlp.make_doc(data)
        if matches := matcher(sample_nlp):
            matches = [
                (nlp.vocab.strings[match_id], start, end)
                for match_id, start, end in matches
            ]
            matches = match_overlap(matches)
            # (o_one, o_two, lbl)
            entities = [offsetter(x[0], sample_nlp, x) for x in matches]
            ner_train_data.append(Example.from_dict(sample_nlp, {"entities": entities}))

    return ner_train_data


# training the model
def train_ner(train_data, nlp):
    # disable pipeline components that won't be changing
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]

    with nlp.disable_pipes(*other_pipes):
        optimizer = nlp.create_optimizer()

        # training for 30 iterations
        for iteration in range(30):

            # shuffling examples before every iteration
            random.shuffle(train_data)

            # batch up the examples using spaCy's minibatch
            batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                nlp.update(
                    batch,  # batch of texts
                    drop=0.5,  # dropout - make it harder to memorise data
                    sgd=optimizer,
                )

    return
    # source: adapted from https://www.machinelearningplus.com/nlp/training-custom-ner-model-in-spacy/

# %% [markdown]
# ### Update the NER model with the new labels and named entities

# %%
# some titles to add the lexicon
titles_to_add = [
    "The Handmaid's Snail",
    "The Matrix",
    "Matrix",
    "Dumb and Dumber",
    "Blacklist",
    "The Conjuring 1",
    "The Conjuring 2",
    "The Conjuring 3",
    "The Exorcist" "The Conjuring",
]

# some actors to add the lexicon
actors_to_add = ["Wahlberg", "Walberg", "Millicent", "Marky Mark", "Mark", "Chiwetel"]

# some roles to add the lexicon
roles_to_add = ["June"]

# some directors to add the lexicon
directors_to_adddd = ["Bob Zemeckis", "James Wan", "Wan", "Michael Chaves"]

# set their labels
ner_set_labels = [
    (movie_names + titles_to_add, "TITLE"),
    (cast_names + actors_to_add, "ACTOR"),
    (character_names + roles_to_add, "ROLE"),
    (directors_to_adddd, "DIRECTOR"),
]

# %% [markdown]
# ### Add cast, character, director, and movie names with their respective labels to NER vocab/lexicon

# %%
for ner in ner_set_labels:
    set_entity_ner(ner, matcher, nlp)

# %% [markdown]
# ### Set up the training data to recognize the new named entities in the corpus
#  this formats each review using spaCy's API, and demarks named entities within the corpus to train

# %%
# grabbing review content and title data
sample_data = [
    str(review["review_title"] + review["content"])
    for movie in movies_with_reviews["movies"]
    for review in movie["reviews"]
]

# a few test sentences to add to the corpus for training
sentences_to_add = [
    "Manifest stars Mark Wahlberg, Elisabeth Moss as June Osborne and directed by Wan.",
    "Dominic Toretto isn't a great character in this story arc.",
]

sample_data = sample_data + sentences_to_add

# format the corpus data using spaCy's API
ner_train_data = setup_entity_training_data(sample_data, matcher, nlp)

# %% [markdown]
# ### Train the NER model

# %%
# train cast, character, and movie names NER
train_ner(ner_train_data, nlp)

# %% [markdown]
# ### Test the new NERs

# %%
# testing with a cast name
# Mark Wahlberg
test_doc_cast = nlp(
    "Mark Wahlberg was the star in Manifest, which also had June Osborne played by Elisabeth Moss and directed by Wan."
)
print("Entities", [(ent.text, ent.label_) for ent in test_doc_cast.ents])

# testing with a character name
# Dominic Toretto
test_doc_role = nlp("One of the worst characters in the movie was Dominic Toretto.")
print("Entities", [(ent.text, ent.label_) for ent in test_doc_role.ents])
# Out:
# Entities [('Mark Wahlberg', 'ACTOR'), ('Manifest', 'TITLE'), ('June Osborne', 'ROLE'), ('Elisabeth Moss', 'ACTOR'), ('Wan', 'ACTOR')]
# Entities [('Dominic Toretto', 'ROLE')]

# %% [markdown]
# ### Chunking again with the new NER's

# %%
# run chunking again, this time with cast and character names added to the NER
for movie in movies_with_reviews["movies"]:
    for review in movie["reviews"]:
        # noun phrase chunking using spaCy with updated lexicon for cast and characters
        review["review_chunks_new"] = [
            chunk.text for chunk in get_np_chunks(review["review_tokens"], nlp)
        ]

# %% [markdown]
# ### Compare new chunks to old chunks without new NER's

# %%
# the chunks from the first go-round
review_chunks = [
    review["review_chunks"]
    for movie in movies_with_reviews["movies"]
    for review in movie["reviews"]
]

# the chunks the second go-round with updated NER
review_chunks_new = [
    review["review_chunks_new"]
    for movie in movies_with_reviews["movies"]
    for review in movie["reviews"]
]

# %% [markdown]
# ### Listing the NP chunks

# %%
# list the review chunks
review_chunks
# Out:
# [['You',
#   'you',
#   'horror films',
#   'I',
#   'topic',
#   'a moment',
#   'I',
#   'male mid sixties',
#   'many others',
#   'all the great and not-so-great horror films',
#   'the ten episodes',
#   "The Handmaid's Tale",
#   'I',
#   'a real horror story',
#   'It',
#   'the entire horror genre',
#   'cotton candy',
#   'each episode',
#   'I',
#   'myself',
#   'tears',
#   'my eyes',
#   'I',
#   'the story',
#   'I',
#   'you',
#   'the acting',
#   'reproach',
#   'almost every movie',
#   'every TV series',
#   'at least one or two characters',
#   'I',
#   'fault',
#   'the performances',
#   'the entire cast',
#   'The sets',
#   'the direction',
#   'the camera',
#   'the intensity',
#   'a story',
#   'a good world',
#   'a story',
#   'faith',
#   'evil intent',
#   'the common people',
#   'me',
#   'it',
#   'I',
#   'I',
#   'better words',
#   'this show',
#   'me',
#   'I',
#   'My daughter',
#   'university',
#   'the U S',
#   'I',
#   'you',
#   'I',
#   'her safety',
#   'every day',
#   'this story',
#   'it'],
#  ['It',
#   'I',
#   'I',
#   'a review',
#   'my life',
#   'more information',
#   'it',
#   'I',
#   'IMDb',
#   'intelligent reviews',
#   'intelligent people',
#   'I',
#   'a few that scream',
#   'ignorance'],
#  ['I',
#   'Its endless parade',
#   'misery',
#   'no hope',
#   'sight',
#   'I',
#   'its always same story line',
#   'the end',
#   'we',
#   'close ups',
#   'Elizabeth Moss huge eyeballs',
#   'she',
#   'you',
#   'sadist',
#   'masochist',
#   'your entertainment',
#   'Me',
#   'I'],
#  ['I',
#   'most people',
#   'these pages',
#   'the difference',
#   'this series',
#   'honesty',
#   'the ones',
#   'who',
#   'reasons',
#   'the viewing experience',
#   'it',
#   'someone',
#   'the negative reviews',
#   'fear',
#   'the worst kind',
#   'delusion',
#   'self delusion',
#   'the delusion',
#   'a person',
#   'themselves',
#   'order',
#   'the truth'],
#  ["The Handmaid's Tale-Seaso",
#   '2- 3 SEASON 1 A masterpiece',
#   'Put feminism',
#   'a moment',
#   'a brilliantly told story',
#   'you',
#   'it',
#   'empowerment',
#   'a leisure activity',
#   'every character',
#   'hero',
#   'villain',
#   'his or her own chance',
#   'Season',
#   'parts',
#   'each carefully framed shot',
#   "The Handmaid's Tale",
#   'the story',
#   'twists',
#   'you',
#   'T V SEASON',
#   "The Handmaid's Tale",
#   'the perfect continuation',
#   'Season',
#   'it',
#   'new shocking conflicts',
#   'Moss Fiennes',
#   'Strahovski',
#   'incredible chemistry',
#   'screen',
#   'this season',
#   'the tension',
#   "The Handmaid's Tale",
#   'every episode',
#   'the writers',
#   'actors',
#   'their talents',
#   'a whole new level',
#   'SEASON',
#   'I',
#   'this show',
#   'season',
#   'I',
#   'I',
#   'so many parallels',
#   'our world',
#   'The Underground Railroad',
#   'the 1860s',
#   'the persecution',
#   'Jews',
#   'the 1940s',
#   'the persecution',
#   'women',
#   'the modern Middle East',
#   'inspirations',
#   'tales',
#   'rebels agitators',
#   'heroes',
#   'a day',
#   'age',
#   'our heroes',
#   'capes',
#   'billion dollar steel armor',
#   'it',
#   'the plain old human spirit',
#   'ass'],
#  ["The Handmaid's Snail The Handmaid's Tale",
#   'the TV adaptation',
#   "Margaret Atwood's dystopian novel",
#   'a right wing religious takeover',
#   'the USA',
#   'women',
#   'the two biggest problems',
#   'the series',
#   'the tortuously slow pace',
#   'the painfully boring performance',
#   'Elizabeth Moss',
#   'the leading role',
#   "the show's executive producers",
#   'her casting',
#   'she',
#   'the role',
#   'a woman',
#   'her fertility',
#   'The other major problem',
#   "The Handmaid's Tale",
#   'a masterpiece',
#   'understatement',
#   'brevity',
#   'the story',
#   'multiple seasons',
#   'the producers',
#   'uninteresting tangents',
#   'the book',
#   'the pace',
#   'show',
#   'an aggravating crawl',
#   'we',
#   'endless scenes',
#   'Offred Moss',
#   'the stairs',
#   'her room',
#   'her garb',
#   'her three default expressions',
#   'brief sequences',
#   'action',
#   'the story',
#   'the above',
#   'almost every other scene',
#   'the gist',
#   'the show'],
#  ['I',
#   'Hate',
#   'June People',
#   'June',
#   'she',
#   'anything',
#   'fact',
#   'she',
#   'she',
#   'the only person',
#   'the world',
#   'these problems',
#   'She',
#   'you',
#   'she',
#   'the show',
#   'She',
#   'the worst character',
#   'the entire show',
#   'I',
#   'the way',
#   'she',
#   'I',
#   'her',
#   'her back',
#   'she',
#   'It',
#   'all these men',
#   'her',
#   'I',
#   'the new Commander',
#   'her',
#   'her place',
#   'All June',
#   'people',
#   'She',
#   'others',
#   'their necks',
#   'She',
#   'the wall',
#   'season',
#   'I',
#   'Janines story',
#   'Season',
#   'season',
#   'I',
#   'June'],
#  ['something',
#   'Television',
#   'Your wait',
#   'IT Strong',
#   'the word',
#   'this series',
#   'little weak people',
#   'the fake reviews',
#   'thumbs',
#   'the actual reviews',
#   'it',
#   'Fear',
#   'a powerful thing'],
#  ['me',
#   'OMG',
#   'I',
#   'Bob Zemeckis',
#   'I',
#   'you',
#   'a winner',
#   'The worst part',
#   'me',
#   'the-board',
#   'a scant few The kid',
#   'who',
#   'Cal Stone',
#   'me',
#   'his dad',
#   'Ben',
#   'who',
#   'the Joey Tribbiani School',
#   'the fart',
#   'I',
#   'his scrunched-up expressions',
#   'I',
#   'It',
#   'a good premise',
#   'I',
#   'it'],
#  ['Great premise',
#   'awful writing',
#   'I',
#   'it',
#   'Someone',
#   'I',
#   'an interesting idea',
#   'a tv show',
#   'About two hundred people',
#   'a plane',
#   'they',
#   'them',
#   'only a few hours',
#   'they',
#   'the idea',
#   'a network',
#   'it',
#   'a bunch',
#   'freshmen',
#   'school',
#   'it',
#   'I',
#   'What',
#   'the world',
#   'anyone',
#   'their right mind',
#   'the viewers',
#   'such lazy writing',
#   'I',
#   'this show',
#   'It',
#   'some sort',
#   'manipulation',
#   'the network',
#   'the unwarned',
#   'your time',
#   'the kind',
#   'show',
#   'the viewer',
#   'a brainless moron',
#   'it'],
#  ['Season',
#   'still NO answers',
#   'anything',
#   'arrrgggg ZERO',
#   'I',
#   'this show',
#   'my dvr',
#   'I',
#   'It',
#   'season',
#   'we',
#   'no answers',
#   'I',
#   'three seasons',
#   'this show',
#   'we',
#   'just a clueless',
#   'we',
#   'we',
#   'day',
#   'All the storylines',
#   'molasses',
#   'a tree',
#   'we',
#   'sustenance',
#   'something',
#   'molasses',
#   'we',
#   'absolutely NOTHING',
#   'this show',
#   'Snails',
#   'these storylines',
#   'What a shame',
#   'it',
#   'season',
#   'it',
#   'Lost',
#   'I',
#   'that road',
#   'it',
#   'I'],
#  ['HO HUM',
#   'most supernatural dramas',
#   'network television',
#   'this one',
#   'concept',
#   'story',
#   'Us weepy relationship schmaltz'],
#  ['OMG',
#   'the point',
#   'I',
#   'all 16 episodes',
#   'I',
#   'I',
#   'a lot',
#   'FF',
#   'the blahdy',
#   'the end',
#   'I',
#   'nothing',
#   'I',
#   'the first episode',
#   'nothing'],
#  ['We',
#   'My wife',
#   'I',
#   'too many network programs',
#   'we',
#   'the concept',
#   'this one',
#   'we',
#   'Zemekis',
#   'it',
#   'the production values'],
#  ['The Episode',
#   'It',
#   'our TV',
#   'this time',
#   'we',
#   'episode',
#   'I',
#   'it',
#   'The story',
#   'episode',
#   'all the signs',
#   'clichés',
#   'The main character',
#   'the whole time',
#   'a wound',
#   'a deer',
#   'a spotlight',
#   'His detective sister',
#   'his wife',
#   'my gods',
#   'His wife',
#   'I',
#   'the stage',
#   'I',
#   'something',
#   'the TV',
#   'selfish woman',
#   'her mouth',
#   'the government agents',
#   'the slightest thing',
#   'them',
#   'the only thing',
#   'they',
#   'an episode',
#   'National security',
#   'I',
#   'this pathetic soap opera'],
#  ['A good premise',
#   'I',
#   'the premise',
#   'it',
#   'it',
#   'The execution',
#   'The mystery',
#   'the core',
#   'the story',
#   'The mystery',
#   'people'],
#  ['the most stupid shows', 'TV'],
#  ['Mixed feelings',
#   'I',
#   'I',
#   'the previews',
#   'this program',
#   'I',
#   'such a focus',
#   'the sci-fi',
#   'you',
#   'it',
#   'aspects',
#   'others',
#   'reminiscence',
#   'a Lost or similar program',
#   'reverse',
#   'I',
#   'this program',
#   'stories',
#   'the passengers',
#   'their old lives',
#   'all the changes',
#   'place',
#   'those five and half years',
#   'The focus',
#   'I',
#   'it',
#   "'s",
#   'real life',
#   'we',
#   'the authorities',
#   'the scientists',
#   'everyone',
#   'their every move',
#   'an answer'],
#  ['It',
#   'some potential',
#   'I',
#   'It',
#   'a low bar',
#   'hurdle',
#   'it',
#   'the first step',
#   'Acting sucks story',
#   'they',
#   'a new way',
#   'the story',
#   'I',
#   'a tear',
#   'it'],
#  ['A Waste',
#   'Pixels',
#   'a couple',
#   'eps',
#   'S1',
#   'it',
#   'it',
#   'The writers',
#   'no indication',
#   'they',
#   'the hollow plot',
#   'the ham actors',
#   'no sense',
#   'character',
#   'We',
#   'richer deeper more realistic characters',
#   '10-15 skits',
#   '1st semester acting class',
#   'community college'],
#  ['it',
#   'The final nail',
#   'the 747 sized coffin',
#   'the flight',
#   "Noah's Ark",
#   'you',
#   'me',
#   'A plane',
#   '5 1/2 years',
#   'the most unbelievable part',
#   'the show'],
#  ['The Matrix',
#   'the Kardashians',
#   'context and misunderstood ideas',
#   'the eastern philosophy',
#   'utterly ridiculous and boring mess',
#   'It',
#   "a shallow people's deep movie"],
#  ['The Matrix',
#   'Dumb',
#   'Some individuals',
#   'Earth',
#   'their previous lives',
#   'them',
#   'a group',
#   'people',
#   'their consciousness',
#   'one body',
#   'who',
#   'all life',
#   'the planet'],
#  ['Awful',
#   'an interesting concept',
#   'itself',
#   'a Trojan horse',
#   'manure',
#   'it',
#   'a ludicrous suckfest',
#   'atrocious CGI'],
#  ['Infinite Shark Jumps',
#   'We',
#   'Walberg',
#   'it',
#   'it',
#   'a great action flick',
#   'They',
#   'the actors',
#   'They',
#   'the budget',
#   'They',
#   'Too much CGI',
#   'not enough people',
#   'bad idea'],
#  ['my Paramount',
#   'free trial',
#   'I',
#   'I',
#   'some explanation',
#   'the entire premise',
#   'the antagonist',
#   "his Dethroner's soul-capturing bullets",
#   'his own head',
#   'any other Nihilist infinite',
#   'the cycle',
#   'that matter',
#   'Boom',
#   'you',
#   'The end',
#   'Glaring oversight',
#   'they',
#   'such a huge plot hole',
#   'you',
#   'ANYONE',
#   'this project',
#   'the audience',
#   'an IQ',
#   'a goldfish',
#   'it',
#   'credit',
#   'just plain dumb fun',
#   'countless other better done action movies'],
#  ['its audience',
#   'Absolutely dreadful movie',
#   'it',
#   'the audience',
#   'they',
#   'the under 12 s'],
#  ['Fast'],
#  ['Hollywood',
#   'mindless Great concept',
#   'very horrid execution Wtf',
#   'all these movies',
#   'who',
#   'money',
#   'stupid mindless action scenes',
#   'Hollywood',
#   'a note',
#   'movies',
#   'Raid Man',
#   'it',
#   'action scenes',
#   'the furious illogical fantasy crap',
#   'pure trash',
#   'the lowest IQ',
#   'people',
#   'people',
#   'who',
#   'their mind'],
#  ['I',
#   'one good thig',
#   'this film',
#   'it',
#   'I',
#   'no good things',
#   'You',
#   'the action scenes',
#   'the worst thing',
#   'the movie',
#   'The visuals',
#   'The story',
#   'its a mess',
#   'The characters',
#   'personality',
#   'I',
#   'them',
#   'Horrible action film'],
#  ['Pure toilet Awful music terrible editing noisy garbage film'],
#  ['This Movie',
#   'a Mess',
#   'all these reincarnations',
#   'these morons',
#   'walls',
#   'ears',
#   'He',
#   'Important information',
#   'more than half the movie',
#   'him',
#   'his memory',
#   'truly infinite idiocy',
#   'this movie',
#   "Chiwetel Ejiofor's acting",
#   "Dylan O'Brien",
#   'scenes'],
#  ['the script writers',
#   'I',
#   'Dylan',
#   'human race sake',
#   'Mark',
#   'the egg',
#   'Chiwetel',
#   'noboby',
#   'I'],
#  ['What',
#   'I',
#   'Who',
#   'The screen play',
#   'the acting',
#   'Who',
#   'Marky Mark',
#   'he',
#   'it',
#   'the movie'],
#  ['I',
#   'money',
#   'this load',
#   'crap',
#   'the movie',
#   'a great start',
#   'things',
#   'the story line',
#   'too many wholes performance',
#   'the action scenes',
#   'Mark',
#   'the time',
#   'the movie',
#   'times',
#   'I',
#   'I',
#   'a movie',
#   'different clothes designs',
#   'the latest car and technology gadgets',
#   'Complete waste',
#   'time'],
#  ['A Worthy Sequel', 'you', 'you', 'this one'],
#  ['Part', 'It', 'we', 'movie movies', 'their predecessor', 'us'],
#  ['Great sequel',
#   'amazing cinema experience',
#   'Best cinema experience',
#   'I',
#   'a while',
#   'full house',
#   'a near silent crowd',
#   'the lack',
#   'plot',
#   'I',
#   'this film',
#   'a continuation',
#   'the story',
#   'it',
#   'a third',
#   'You',
#   'it',
#   'the ending',
#   'the setting',
#   'time',
#   'I',
#   'some people',
#   'Millicent Simmonds',
#   'this film',
#   'Cillian Murphy',
#   'her',
#   'it',
#   'Emily Blunt',
#   "'s",
#   'Millicent',
#   'the spotlight',
#   'she',
#   'it',
#   'I',
#   'the sequel',
#   'the first film',
#   'the scenes',
#   'some jump scares',
#   'them',
#   'the lack',
#   'scares',
#   'this film',
#   'big action pieces',
#   'the big screen',
#   'I',
#   'preferred more silent scenes',
#   'sound',
#   'a jump scare element',
#   'big explosions',
#   'loud sounds',
#   'the action',
#   'the sound design',
#   'we',
#   'Regans',
#   'sound',
#   'completely Favourite scene',
#   'the opening big action scenes',
#   'a good origin',
#   'the world',
#   'it',
#   'The only thing',
#   'me',
#   'the theme',
#   'family',
#   'It',
#   'every man',
#   'himself',
#   'we',
#   'a few moments',
#   'the theme',
#   'family',
#   'you',
#   'Regan',
#   'Marcus',
#   'their father',
#   'the film',
#   'the family',
#   'safety',
#   'this film',
#   'horror',
#   'your taste',
#   'you',
#   'the sound and production design'],
#  ['People',
#   'these ratings',
#   'thing',
#   'a pain point',
#   'horror suspense movies',
#   'a either a character',
#   'something',
#   'drama',
#   'or further the story'],
#  ['a lot',
#   "Krasinski's character",
#   'a big hole',
#   'I',
#   'the opening scene sequence',
#   'a film',
#   'a horror movie',
#   'the title card Day',
#   'the beginning',
#   'A Quiet Place',
#   'Part',
#   'you',
#   'you',
#   'a treat',
#   'it',
#   'a truly great sequence',
#   'I',
#   'a huge proponent',
#   'jump-scares',
#   'this movie',
#   'me',
#   'I',
#   'This sequence',
#   'the tone',
#   'the film',
#   'everything'],
#  ['the big screen',
#   'I',
#   'an advanced screening',
#   'I',
#   'any reviews',
#   'I',
#   'the best way',
#   'it',
#   'reviews',
#   'it',
#   'anything',
#   'the first one',
#   'I',
#   'part',
#   'it',
#   'It',
#   'start',
#   'the pacing',
#   'great acting Krasinski',
#   'writer',
#   'director',
#   'it',
#   'I',
#   'more movies',
#   'this calibre',
#   'I',
#   'anything',
#   'any reviews',
#   'this thrilling movie',
#   'the cinema',
#   'the big screen',
#   'it',
#   'you'],
#  ['I',
#   'it',
#   'such a waste',
#   'time',
#   'Silly scenarios',
#   'corny dialogue',
#   'The children',
#   'they',
#   'obstacles',
#   'problems'],
#  ['I', 'something', 'it'],
#  ['the remix',
#   'a few new characters',
#   'the first but more places',
#   'a few more things',
#   'the same feel',
#   'us',
#   'the same exact place',
#   'the first one',
#   'The whole thing'],
#  ['A tremendous sequel',
#   'all the aspects',
#   'the first such a surprise',
#   'even more relentless chaos',
#   'creature feature action',
#   'A Quiet Place',
#   'a massive surprise',
#   'brilliant concepts',
#   'creativity',
#   'any film',
#   'it',
#   'a bottle',
#   'this sequel',
#   'They',
#   'the ante',
#   'the board',
#   'insane intensity',
#   'pieces',
#   'just overall absolute action thrills'],
#  ['the first movie',
#   'my opinion',
#   'we',
#   'a glimpse',
#   'Day',
#   'this movie',
#   'places',
#   'it',
#   'a couple things',
#   'my friend',
#   'I',
#   'place',
#   'we',
#   'it',
#   'part',
#   'I',
#   'the pacing',
#   'the storyline',
#   'the acting',
#   'top notch',
#   'a doubt',
#   'John',
#   'use',
#   'his character',
#   'act',
#   'it',
#   'Cillian',
#   'an actor',
#   'Emily Millicent',
#   'Noah Jupe',
#   'his scenes',
#   'the creatures',
#   'it',
#   'the sound effects',
#   'you',
#   'certain spots'],
#  ['A place', 'logic'],
#  ['Krasinski',
#   'us',
#   'A NUTSHELL',
#   'the very first movie',
#   'I',
#   'an actual theater',
#   'over a year',
#   'A Quiet Place II',
#   'the first movies',
#   'its theater release',
#   'I',
#   'a press screening',
#   'a local theater',
#   'just 9 other film critics',
#   'The movie',
#   'A Quiet Place',
#   'the horrific events',
#   'home',
#   'the Abbott family',
#   'the terrors',
#   'the outside world',
#   'they',
#   'the creatures',
#   'sound',
#   'the only threats',
#   'the sand path'],
#  ['A quieter place',
#   'a movie',
#   'the anxiety',
#   'the movie',
#   'you',
#   'Spoilers',
#   'no story',
#   'no origin',
#   'these mindless creatures',
#   'earth',
#   'things',
#   'sound',
#   'They',
#   'the creatures',
#   'this movie',
#   'the main characters',
#   'themselves',
#   'noise',
#   'dirty feet',
#   'No new revelations',
#   'plot twists',
#   'anything',
#   'It',
#   'a lovely cliff hanger',
#   'you',
#   'it',
#   'streaming'],
#  ['I',
#   'A Quiet Place 2 A solid sequel',
#   'I',
#   'it',
#   'it',
#   'the less horror',
#   'more tension action',
#   'Cillian Murphy',
#   'an alt',
#   'John Krasinski',
#   'John',
#   'a third film'],
#  ['I',
#   'no idea',
#   'what movie',
#   'everyone',
#   'a good movie',
#   'these people',
#   'idiots',
#   'no way',
#   'them',
#   'years',
#   'anything',
#   'Boring',
#   'hell'],
#  ['Different Director Different Type',
#   'Conjuring',
#   'Film',
#   'I',
#   'The Conjuring',
#   'James Wan',
#   'This film',
#   'Michael Chaves',
#   "Wan's films",
#   'this one',
#   'The script',
#   'the horror elements',
#   'virtually no character development',
#   'This film',
#   'an interesting story',
#   'interesting characters'],
#  ['the Devil',
#   'them',
#   'this trash',
#   'a review',
#   'this movie',
#   'you',
#   'suspense tension demons',
#   'decent cinematography',
#   'the first films',
#   'you',
#   'it',
#   'the almost 2 hours',
#   'pieced together rubbish',
#   'zero character development',
#   'the end',
#   'you',
#   'you',
#   'what',
#   'The special effects',
#   'the dialog',
#   'the plot',
#   'Plot holes plot holes',
#   'James Wan',
#   'you',
#   'Patrick Wilson',
#   'Vera Farmiga'],
#  ['The Devil',
#   'his name',
#   'You',
#   'the Warrens',
#   'Catholic superheroes',
#   'us',
#   'the world',
#   'a constant battle',
#   'demons',
#   'the Hollywood Reporter',
#   'the early 1960s',
#   'Ed Warren',
#   'a relationship',
#   'an underage girl',
#   "Lorraine's knowledge",
#   'her 70s',
#   'Judith Penney',
#   'a sworn declaration',
#   'she',
#   'the Warrens house',
#   "Ed's lover",
#   'four decades'],
#  ['Fell Asleep Boring',
#   'Also Hollywood',
#   'just a tip',
#   'sound',
#   'a body distortion',
#   'bones',
#   'A host',
#   'the demon',
#   'better stories',
#   'this silly contortionist nonsense'],
#  ['What',
#   'me',
#   'the original recording',
#   'the exorcism',
#   'they',
#   'the credits',
#   'I',
#   'it',
#   'What',
#   'the movie lacks',
#   'originality',
#   'I',
#   'it',
#   'a movie',
#   'the viewer',
#   'what',
#   'I',
#   'I',
#   'the reason',
#   'I',
#   'the fast and furious movies',
#   'I',
#   'each new sequel',
#   'the previous one mediocre',
#   'it',
#   'they',
#   'What',
#   'me',
#   'the original recording',
#   'the exorcism',
#   'they',
#   'the credits',
#   'I',
#   'it'],
#  ['No horror',
#   'this film',
#   'nothing',
#   'this film',
#   'the few jump scares',
#   'it',
#   'you',
#   'you',
#   'your horror films'],
#  ['Really not good pales',
#   'comparison',
#   'This sequel',
#   'The story',
#   'inconsistencies',
#   'silliness',
#   'it',
#   'it',
#   'part',
#   'the original Warren saga',
#   'The directing',
#   'the plot',
#   'heroes',
#   'villain',
#   'a good solid horror story',
#   "the Warren's cases",
#   'good solid actors',
#   'a movie',
#   'their talents'],
#  ['yourself',
#   'the face',
#   'It',
#   'bad editing',
#   'I',
#   'I',
#   'a tough trip',
#   'an they',
#   'the iconic Exorcist poster art',
#   'some reason',
#   'you',
#   'the loudest exorcism',
#   'It',
#   'what',
#   'you',
#   'a low-effort early 00s edgy remake',
#   'The Exorcist',
#   'a Subtitle',
#   'Conjuring',
#   'it',
#   'the same ballpark',
#   'the first Annabelle',
#   'the actual Conjuring movies',
#   'The only entry',
#   'I',
#   'confidence',
#   'The Nun',
#   "Even the Conjurverse's bread and butter jump scares",
#   'you',
#   'them',
#   'Annabelle',
#   'jump scares',
#   'I',
#   'the Conjurverse',
#   'a mixed bag',
#   'I',
#   'the entire shared universe',
#   'a mainline entry',
#   'I',
#   'a contrarian',
#   'I',
#   'a lesser-but-fun sequel',
#   'a new director',
#   'a chance',
#   'his skills',
#   'La Llorona',
#   'that mess',
#   'a sufficient scary spirit entity',
#   'none',
#   'no real demon',
#   'supernatural entity',
#   'It',
#   'just SOME LADY',
#   'her dad',
#   'Warrens',
#   'this movie',
#   'poor Patrick',
#   'Vera',
#   'The Warren characters',
#   '3 different investigations',
#   'more pressing issues',
#   'The characters',
#   'no development',
#   'You',
#   'what',
#   "It'a",
#   'loud nonsense',
#   'ridiculous legal defenses',
#   'demonic possession',
#   'a real person',
#   'The whole thing',
#   'a technically and morally bankrupt garbage fire',
#   'you',
#   'it',
#   'HBOmax',
#   'something',
#   'a theater',
#   'it',
#   'you',
#   'the pandemic scare',
#   'it',
#   'your living room',
#   'you',
#   'the other patrons',
#   'you',
#   'the horrific writing dialogue',
#   'sense',
#   'the 50th time'],
#  ['I',
#   'these high ratings',
#   'we',
#   'the same movie',
#   'the franchise',
#   'a film',
#   'it',
#   'Nothing',
#   'the film',
#   'it',
#   'it',
#   'the entire time',
#   'absolutely nothing',
#   'here story',
#   'we',
#   'every other demon-centered horror film',
#   'Nothing',
#   'nothing',
#   'this film',
#   'any means',
#   'it',
#   'the worst horror film',
#   'I',
#   'it',
#   'I'],
#  ['Warner Bros',
#   'their Production Company',
#   'the Ugliest Horror movie',
#   'I',
#   'I',
#   'not even a single scare scene',
#   'such a reputed sequel',
#   'Warner Bros Company',
#   'these kind',
#   'Stories',
#   'I',
#   'it',
#   'it',
#   'some sort',
#   'Good plot',
#   'it',
#   'a movie'],
#  ['People',
#   'The premise',
#   'I',
#   'high hopes',
#   'the plot',
#   'time',
#   'any kind',
#   'consistent manner',
#   'this film',
#   'the same time',
#   'I',
#   'a film',
#   'It',
#   'a small subtitle day',
#   '1 day',
#   'it',
#   'more sense'],
#  ['You', 'Awake', 'this Dull dull dull'],
#  ['The inevitable annoying main charcaters',
#   'it',
#   'these types',
#   'films',
#   'the irritating angsty teenager',
#   'the smart little kid',
#   'who',
#   'the secret',
#   'the incredibly annoying Mom',
#   'who',
#   'she',
#   'the world'],
#  ['I',
#   'quite a fan',
#   'Netflix films',
#   'the worst ones',
#   'I',
#   'I',
#   'open house',
#   'Whoever',
#   'charge',
#   'the trailer',
#   'a really good job',
#   'they',
#   'the film',
#   'I',
#   'no explanation',
#   'everything',
#   'You',
#   'something',
#   'no reason',
#   'it',
#   'What',
#   'the hell',
#   'the ending',
#   'I',
#   'the noise',
#   'the end',
#   'she',
#   'You',
#   'the film',
#   'what',
#   'they',
#   'they',
#   'a cop',
#   'I',
#   'my time'],
#  ['I', 'a full review', 'it', 'it', 'your time', 'it'],
#  ['Watch',
#   'I',
#   'it',
#   'only about 25 minutes',
#   'they',
#   'a church',
#   'they',
#   'the daughter',
#   'Someone',
#   'we',
#   'her',
#   'I',
#   'this point',
#   'they',
#   'Utter nonsense',
#   'terrible writing',
#   'I',
#   'it',
#   'the trusty internet',
#   'reviews',
#   'a good decision',
#   'Some great actors',
#   'this movie',
#   'we',
#   'decent writers',
#   'a good director',
#   'Barry Pepper',
#   'Saving',
#   'Private Ryan',
#   "F's sake",
#   'Netflix',
#   'quantity',
#   'quality model',
#   'it'],
#  ['lousy waste', 'time', 'the worst movies', 'I', 'my life'],
#  ['I',
#   'more than 15 minutes',
#   'Just pure garbage',
#   'I',
#   'it',
#   '2 hours',
#   'this script',
#   'some recent news',
#   'your own conclusions'],
#  ['A terrible movie', 'a terrible ending', 'what', 'the heck'],
#  ['It',
#   'Gina Rodriguez',
#   'Jennifer Jason Leigh',
#   'my favorite films',
#   'Annihilation',
#   'this film',
#   'I',
#   'the production values',
#   'a limited budget',
#   "Christopher Nolan's name",
#   'this film',
#   'you',
#   'good writers',
#   'Skillful writing',
#   'the cornerstone',
#   'all good entertainment',
#   'a lot',
#   'problems',
#   'a low budget',
#   'bad special effects',
#   'you',
#   'the story',
#   'it',
#   'This film',
#   'part',
#   'the dynamics',
#   'the characters',
#   'the central concept',
#   'the story',
#   'an idea',
#   'the characters',
#   'the viewers',
#   'High concept films',
#   'Children',
#   'Men',
#   'media',
#   'high-concept',
#   'the very beginning',
#   'it',
#   'you',
#   'the full effect',
#   'the concept',
#   'Awake',
#   'these things',
#   'it',
#   'an uncomfortable middle ground',
#   'the film',
#   'a B movie'],
#  ['Wasted opportunity', 'My guess', 'the pitch', 'Netflix', 'the greenlight'],
#  ['people',
#   'who',
#   'it',
#   'they',
#   'a few days',
#   'their car',
#   'a person',
#   'who',
#   'sleep deprivation',
#   'childhood',
#   'I',
#   'you',
#   'it',
#   'You',
#   'people',
#   'kids',
#   'so many questions'],
#  ['I', 'a good story', 'whoever'],
#  ['Nothing',
#   'sense',
#   'this film',
#   'The idea',
#   'he',
#   'story',
#   'a mess',
#   'the beginning',
#   'the end',
#   'Someone',
#   'a little effort',
#   'a better script'],
#  ['A refreshingly non-Hollywoodish realistic-feel',
#   'sci',
#   'the the critics',
#   'this one',
#   'I',
#   'a state',
#   'anxiety',
#   'suspense',
#   'start'],
#  ['the negative reviewers',
#   'This movie',
#   'It',
#   'a movie',
#   'you',
#   'moment',
#   'action Judge',
#   'your own viewpoints',
#   'it'],
#  ['This movie', 'I', 'the first few minutes', 'it', 'it', 'the watch'],
#  ['you',
#   'sci-fi and apocalypse movies',
#   'this movie',
#   'Acting',
#   'I',
#   'what',
#   'the outcome',
#   'the movie',
#   'the same old predictable movies',
#   'an interesting action packed watch',
#   'it',
#   'a movie',
#   'It',
#   'the point'],
#  ['Avengers', 'It', 'the actual story', 'the movie', 'they', 'everyone'],
#  ['This series'],
#  ['this Movie',
#   'science fiction',
#   'The movie',
#   'I',
#   'older fans',
#   'this crap',
#   'The franchise',
#   'its character',
#   'the directors',
#   'it',
#   'it',
#   'these stupid marvel movies',
#   'I',
#   'the trend',
#   'universe movies',
#   'they',
#   'the same plot',
#   'the same faces',
#   'new antagonists',
#   'antiheros',
#   'the fans',
#   'the cash',
#   'Godzilla',
#   'universe crap',
#   'successful masterpiece',
#   'that endless amount',
#   'unnecessary sequels',
#   'the same titles',
#   'who',
#   'this chapter',
#   'People',
#   'life',
#   'Cars',
#   'space',
#   'Freakish Destructive technology',
#   'maze runner',
#   'maybe The Watch',
#   'your own risk'],
#  ['I',
#   'a fan',
#   'the franchise',
#   'the first movie',
#   'i',
#   'it',
#   'the drain',
#   'The story',
#   'too predictable Action scenes',
#   'the top',
#   'previous films',
#   'them',
#   'they',
#   'a lot',
#   'forced humour',
#   'Ludacris',
#   'Roman Pearce',
#   'his real name'],
#  ['Trash It', 'just a waste', 'time', 'the worst movies', 'I', 'this series'],
#  ['1 star',
#   'a lot',
#   'this movie',
#   'you',
#   'a good movie',
#   'you',
#   'you',
#   'the top'],
#  ['Trash Big full CGI Action'],
#  ['We', 'family'],
#  ['your time',
#   'the dumbest movie',
#   'I',
#   'the fast and furious series',
#   'story',
#   'too much randomn explosions',
#   'characters',
#   'no consequences',
#   'anything',
#   'One guy',
#   'millions',
#   'times',
#   'bullets',
#   'jacket',
#   'he',
#   'a scratch qnd',
#   'a car',
#   'him',
#   'he',
#   'I',
#   'they',
#   'a car',
#   'space'],
#  ['Waste', 'time', 'money', 'I', 'my 30 dollars'],
#  ['A Delirious Little Escape-package',
#   'The Fun',
#   'THE OPEN MINDED 🚀',
#   'A Good Old Fashioned B',
#   'i',
#   'g',
#   'Screen Review'],
#  ['It',
#   'it',
#   'me',
#   'It',
#   'incredibility and stupendous stunts',
#   'I',
#   'magnets',
#   'a car',
#   'space',
#   'I',
#   'it',
#   'my brain',
#   'F9',
#   'you',
#   'senseless movies',
#   'your street',
#   'It',
#   'me',
#   'I',
#   'this movie'],
#  ['The best worst movie',
#   'I',
#   'My friend',
#   'his water',
#   'the truck',
#   'I',
#   'exactly what',
#   'I',
#   'The fast and furious franchise',
#   'movies',
#   'fi action',
#   'The absolute audacity',
#   'these directors',
#   'you guys',
#   'the goon',
#   'a steel billboard',
#   '80 MPH',
#   'this movie',
#   'I',
#   'Jacob',
#   'John Cena',
#   'him',
#   'me',
#   'Also the fact',
#   'they',
#   'a working spaceship',
#   'like 5 hours',
#   'I',
#   'this beautiful train wreck'],
#  ['This series',
#   'crime movie',
#   'a car racer',
#   'FBI',
#   'a HERO',
#   'This series',
#   'season'],
#  ['Cheesy',
#   'Fun',
#   'theaters',
#   'a year',
#   'the Covid',
#   'The past couple',
#   'Fast and Furious films',
#   'storylines',
#   'director Justin Lin',
#   'the camera directing',
#   'the late Paul Walker'],
#  ['Action',
#   'you',
#   'action',
#   'this movie',
#   'you',
#   'the long running time',
#   'an hour',
#   'the story lines',
#   'every penny',
#   'my time',
#   'cinema'],
#  ['These movies',
#   'fun trash',
#   'you',
#   'you',
#   'I',
#   'what',
#   'I',
#   'I',
#   'it',
#   'I',
#   'what',
#   'these movies',
#   'Charlize Theron',
#   'I',
#   'she',
#   'a bad performance',
#   'Vin Diesel',
#   'Vin Diesel',
#   'everyone',
#   'exactly what',
#   'you',
#   'them',
#   'Nathalie Emmanuel',
#   'me',
#   'she',
#   'the marketing',
#   'me',
#   'the action',
#   'plot',
#   'they'],
#  ['entertainment',
#   'Critics',
#   'movie',
#   'fun',
#   'entertainment',
#   'Movie',
#   'the end',
#   'other movies',
#   'this franchise',
#   'Action sequences',
#   'The mid-credit scene',
#   'me',
#   'return',
#   'Shaw'],
#  ['fun movie',
#   'People',
#   'him',
#   'some reason',
#   'some respect',
#   'his name',
#   'JOHN CENA',
#   'We',
#   'him',
#   'ending',
#   '👀 👀 noiiice'],
#  ['Probs', 'the series', 'probs', 'a prety solid movie', 'I'],
#  ['Damn F9',
#   'so AWESOME',
#   'FANTASTIC',
#   'I',
#   'John Cena',
#   'it',
#   'the brother',
#   'Dominic Toretto',
#   'Mia Toretto',
#   'I',
#   'it'],
#  ['Spaderrrrr',
#   'my account',
#   'James Spader',
#   'I',
#   'the show',
#   'binge',
#   'it',
#   'it',
#   'He',
#   'what',
#   'he',
#   'it',
#   'a pleasure',
#   'watching'],
#  ['everything',
#   'this show',
#   'Lizzy James Spader',
#   'his roll',
#   'Raymond Reddington',
#   'I',
#   'all the characters',
#   'the show top rate',
#   'Megan Boone',
#   'the character',
#   'Elizabeth This character',
#   'self',
#   'it',
#   'my nerves',
#   'This character',
#   'anything',
#   'she',
#   'the best thing',
#   'it',
#   'protocol',
#   'the team',
#   'danger',
#   'Reddington',
#   'who',
#   'her',
#   'he',
#   'the lines',
#   'The fact',
#   'the show',
#   'the really bad guys',
#   'Lizzy',
#   '6 other characters',
#   'some focus',
#   'I',
#   'the background story',
#   'her',
#   'Reddington',
#   'I',
#   'all the drama',
#   'all the dumb selfish things',
#   'Elizabeth',
#   'a turn',
#   'Whoever',
#   'the writer',
#   'this character',
#   'what',
#   "Lizzy's miraculous healing powers",
#   'She',
#   'the face',
#   'a man',
#   'a scratch',
#   'her',
#   'She',
#   'black eyes',
#   'weeks',
#   'the show',
#   'the healing process',
#   'iron',
#   'Lizzy',
#   'guys',
#   'it',
#   'a rest',
#   'a great show',
#   'intrigue espionage',
#   'edge',
#   'your seat stories',
#   'a soap opera',
#   'a bad leading actress',
#   'I TRULY',
#   'this show',
#   'I',
#   'a 9 rating'],
#  ['my favorite shows',
#   'i',
#   'Spader',
#   'the character',
#   'the love',
#   'god',
#   'someone',
#   'elisabeth',
#   'her',
#   'the show',
#   'iritating character',
#   'a bad combo',
#   'her',
#   'we',
#   'the series',
#   'our eyes'],
#  ['Elizabeth Keen',
#   'such an idiot',
#   'The only possible end',
#   'this serie',
#   'I',
#   'Red',
#   'Elizabeth betrayals',
#   'a bullet',
#   'her head',
#   'his life',
#   'a character',
#   'I',
#   'her'],
#  ['Elizabeth Keen',
#   'the second season',
#   'cop shows',
#   'this one',
#   'a great watch',
#   'Reddington',
#   'I',
#   'the side hustle',
#   'he',
#   'the FBI',
#   'cases',
#   'Liz Keen',
#   'the show',
#   'you'],
#  ['James Spader',
#   'a great character',
#   'I',
#   'people',
#   'a good enjoyable show',
#   'it',
#   'reality',
#   'Real governments',
#   'law enforcement organizations',
#   'a grip',
#   'Batman',
#   'he',
#   'The delineation',
#   "James Spader's Raymond Reddington",
#   'any hang ups',
#   'you',
#   'the plot',
#   'I',
#   'such a good performance',
#   'character study',
#   'a fictional show',
#   'reality',
#   'It',
#   'a real good character',
#   'I',
#   'Spader',
#   'this one',
#   'every respect',
#   'yourself',
#   'people',
#   'It',
#   'a good show'],
#  ['I',
#   'a review',
#   'The Blacklist',
#   'half',
#   'season',
#   'I',
#   'an addendum',
#   'a warning',
#   'you',
#   "Agent Keen's character",
#   'the worst part',
#   'Megan Boone',
#   'a worse actress',
#   'each episode',
#   'I',
#   '5 seasons',
#   'the brilliant James Spader',
#   'even the most incompetent amateur actor',
#   'Boone',
#   'Begs',
#   'the question',
#   'she',
#   'the part',
#   'the first place',
#   'the height',
#   'her carreer',
#   'a walk',
#   'The Bold',
#   'the Beautiful',
#   'I',
#   'it',
#   'a bit',
#   'wonderful nepotism',
#   'the hands',
#   'some related Hollywood boss Bottom line',
#   'She',
#   'a horrific actress',
#   'show'],
#  ['One Glorious Actor',
#   'A Difference',
#   'The Blacklist',
#   'the best TV show',
#   'you',
#   'it',
#   'an original storyline',
#   'remarkable cinematography',
#   'It',
#   'its 3rd season',
#   'The Blacklist',
#   'it',
#   'no Breaking Bad or Mr Robot',
#   'Fargo',
#   'Just what',
#   'its appeal'],
#  ['the most creative unique shows',
#   'television',
#   'James Spader',
#   'whole Keen mission',
#   'he',
#   'the TV show',
#   'the tubes',
#   'the original storyline',
#   'It',
#   'a great show',
#   'you',
#   'it'],
#  ['I',
#   'Kate Kaplan',
#   'the bullet',
#   'the head',
#   'The Blacklist series',
#   'the scope',
#   'new and exciting directions Series',
#   'much the same way',
#   'The whole series',
#   'escapism',
#   'Reddington James Spader',
#   'screen role',
#   'the most likable TV villains',
#   'all time'],
#  ['Good show',
#   'I',
#   'this show',
#   'higher ratings',
#   'it',
#   'that Lizzie lady',
#   'who',
#   'the most annoying person',
#   'the whole show',
#   'She',
#   'her own friends',
#   'her own stupidity',
#   'the writers',
#   'the show',
#   'her',
#   'her husband',
#   'The show',
#   'her',
#   'I',
#   'it',
#   'her',
#   'her',
#   'I',
#   'higher and much higher rating',
#   'I',
#   'the show',
#   'that lady',
#   'a major turn'],
#  ['it',
#   'I',
#   'this show',
#   'it',
#   'unique approach',
#   'the foibles',
#   'humanity',
#   'it',
#   'Tom',
#   'I',
#   'Liz',
#   'Reddington',
#   'the past few seasons',
#   'her character',
#   'she',
#   "Red's her daddy",
#   'who',
#   'this flimsy sister character',
#   'they',
#   'She',
#   'me',
#   'Liz-either flat out shoot Red',
#   'another set',
#   'You',
#   'the fun',
#   'this master mind criminal',
#   'you'],
#  ['Not smart people',
#   'I',
#   'Liz Ressler',
#   'an idndication',
#   'the competence',
#   'actual FBI agents',
#   'the country',
#   'they',
#   'a surveillance',
#   'the criminal'],
#  ['Elizabeth Keen',
#   'an annoying character',
#   'several seasons',
#   'the Keen',
#   'Red storyline',
#   'the series',
#   'Bad concept',
#   'poor writing'],
#  ['WE', 'A SEASON', 'MANY UNANSWERED QUESTIONS'],
#  ['nothing',
#   'the viewer',
#   'this journey',
#   'I',
#   'a key word',
#   'this show',
#   'it',
#   'evolution',
#   'so many levels',
#   'the characters',
#   'the story',
#   'even the content',
#   'the story',
#   'technology'],
#  ['WE',
#   'A SEASON 4 Netflix',
#   'ya thing',
#   'This series',
#   'just something',
#   'any other other show',
#   'I',
#   'a show',
#   'all 3 seasons',
#   'about 2 days',
#   'it',
#   'me',
#   'it',
#   'Season',
#   'season',
#   'the finale',
#   'it',
#   'I',
#   'this show',
#   'it',
#   'I',
#   'it',
#   'Bitcoin lol',
#   'me',
#   'I',
#   'good taste',
#   'this show',
#   'Netflix',
#   'it',
#   'production quality',
#   'I',
#   'the slightest errors',
#   'scenes',
#   'it',
#   'TIME',
#   'THE SHOW',
#   'BUY',
#   'SOME GENCOIN',
#   'I'],
#  ['it',
#   'I',
#   'the professional critics',
#   'no clue',
#   'what',
#   'a good TV show',
#   'Rotton Tomatoes',
#   'the critics',
#   'it',
#   'the viewers',
#   'it',
#   'you',
#   'the show'],
#  ['Excellent hidden gem',
#   'it',
#   'you',
#   'Billions Ozark',
#   'Silicon Valley',
#   'you',
#   'this one',
#   'some reason',
#   'this series',
#   'it',
#   'lots',
#   'people',
#   'it',
#   'I',
#   'it',
#   'I',
#   'its'],
#  ['Flippin Fantastic',
#   'This show',
#   'I',
#   'more people',
#   'it',
#   'it',
#   'a well-known cable channel tons',
#   'people',
#   'it',
#   'I',
#   'the grittiness',
#   'it',
#   'they',
#   'the juxtaposition',
#   'cultures',
#   'Miami'],
#  ['StartUp',
#   'I',
#   'the show',
#   'itself',
#   'me',
#   'all ten episodes',
#   'IMDb',
#   'no need',
#   'I',
#   'people',
#   'Crackle',
#   'their endeavor',
#   '100 free original content',
#   'commercials',
#   'they',
#   'I',
#   'the high production value',
#   'the superb acting talent',
#   'StartUp',
#   'a small fortune',
#   'enough eyeballs',
#   'a season',
#   'any other shows',
#   'the way',
#   'Hulu',
#   'they',
#   'free accounts',
#   'what',
#   'Crackle',
#   'the review',
#   'The acting',
#   'no weak spots',
#   'What',
#   'the plot',
#   'Digital currency',
#   'our future',
#   'the road',
#   'the reasons',
#   'StartUp',
#   'the first series',
#   'I',
#   'the content',
#   'Lastly Miami',
#   'a powerful role',
#   'the series',
#   'It',
#   'capability',
#   'something',
#   'something',
#   'StartUp',
#   'it'],
#  ['This rate', 'Ronald', 'only Ronald'],
#  ['a good show', 'they', 'good writers', 'The beginning'],
#  ['The Wire',
#   'I',
#   'directing',
#   'acting',
#   'such explosive and fresh storytelling',
#   'Every episode',
#   'me',
#   'a whiplash',
#   'plot twists',
#   'me',
#   'I',
#   'I',
#   'all 10 episodes'],
#  ["Crackle's hidden crown juwel",
#   'The show',
#   'almost everything',
#   'humor drama thriller',
#   'the je',
#   'sais quoi'],
#  ['StartUp',
#   'I',
#   'the final episode',
#   'this series',
#   'it',
#   'the same time',
#   'It',
#   'you',
#   'something',
#   'you',
#   'obstacles',
#   'the way',
#   'Edi Otmara Adam',
#   'Martin Freeman',
#   'their roles',
#   'people',
#   'something',
#   'this series',
#   'a try',
#   'It',
#   'a bit',
#   'everything',
#   'you',
#   'you',
#   'the underdogs',
#   'they',
#   'the story',
#   'Even Wayne Knight',
#   'it',
#   'a few chuckles',
#   'Kudos',
#   'Crackle',
#   'us',
#   'this wonderful new series',
#   'hope',
#   'a second season',
#   'the near future'],
#  ['IT', 'noobs Technology', 'that startups', 'funding', 'Poor', 'the list'],
#  ['Mediocre',
#   'you',
#   'sex',
#   'the first episode',
#   'your attention',
#   'you',
#   'a good story',
#   'you',
#   'The characters',
#   "the plotline predictable and boring IMBD's description",
#   'organised crime',
#   'I',
#   'you',
#   'something',
#   'hi-tech crime watch Mr Robot StartUp',
#   'a show',
#   'some great actors',
#   'the writing',
#   'imagination'],
#  ['hollywood movie',
#   'cheap recycled comedy',
#   'What',
#   'The absolute sign',
#   'hollywood',
#   'cash cows'],
#  ['A mess',
#   'a movie',
#   'the type-cast A-Listers',
#   'it',
#   'It',
#   'a compilation',
#   'overly loud gory and explosive action scenes',
#   'characters',
#   'the name',
#   'plot progression',
#   'comedy',
#   'The plot',
#   'humour',
#   'it',
#   'times',
#   'the slapstick style',
#   'poor casting choices'],
#  ['Fun', 'I', 'only part', 'i', 'part', 'cinemas', 'Hitmans', 'wife'],
#  ['I', 'an account', 'I', 'Terrible script', 'I'],
#  ['An incredibly awesome sequel',
#   'you',
#   'a sequel',
#   'The movie',
#   'It',
#   'action comedy',
#   'brilliance',
#   'the perfect cast',
#   'you',
#   'I',
#   'you',
#   'So many movie people references',
#   'it',
#   'laughs',
#   'the seriousness',
#   'The ending',
#   'the whole cinema',
#   'you',
#   'the credit scene'],
#  ['The worst movie',
#   'time',
#   'your life',
#   'I',
#   'this movie',
#   'my dad',
#   'We',
#   'much just a fun action comedy',
#   'some talented actors',
#   'the fact',
#   'I',
#   'an hour',
#   'a half',
#   'my life',
#   'this piece',
#   'utter garbage',
#   'me',
#   'belief',
#   'Ryan Reynolds',
#   'my respect',
#   'the man',
#   'Deadpool',
#   'It',
#   'my mind',
#   'the producers',
#   'who',
#   'you',
#   'a stupid idiot',
#   'who',
#   'the most predictable and unfunny jokes',
#   'You',
#   'I',
#   'at least one father',
#   'son',
#   'their hard earned cash',
#   'this soulless farce',
#   'a movie',
#   'I',
#   'my mistake',
#   'support',
#   'this nonsense'],
#  ['time', 'I', 'mistake', 'i', 'yo', 'this silly movie'],
#  ['Awful',
#   'the worst film',
#   'even the worst film',
#   'this century',
#   'the film',
#   'the actors',
#   'this case',
#   'the principal actors',
#   'such an awful job',
#   'it',
#   'relief',
#   'acting',
#   'some actors',
#   'others',
#   'they',
#   'you',
#   'clips',
#   'this film',
#   'an ac ting class',
#   'the actors',
#   'The script',
#   'The photography',
#   'the music',
#   'this garbage',
#   'sets',
#   'it',
#   'an embaressment',
#   'the producers',
#   'I',
#   'the title'],
#  ['No sense', 'it', 'No story line acting', 'it', '14 year olds'],
#  ['F word',
#   'you',
#   'the F word',
#   'this movie',
#   'you',
#   'It',
#   'middle schoolers',
#   'It',
#   'the whole show',
#   'The plot',
#   'the place',
#   'I',
#   'this movie'],
#  ['the best sequels',
#   'I',
#   'an early premiere',
#   'My 1,300 review',
#   'Patrick Hughes',
#   'such an extravagant movie',
#   'Samuel L Jackson',
#   'he',
#   'his 70 s',
#   'it',
#   'I',
#   'Michael Bryce Ryan Reynolds character',
#   'everything',
#   'the events',
#   'a hilarious way',
#   'the chaos',
#   'The same impressive aspect',
#   'Samuel',
#   'it',
#   'Morgan Freeman',
#   'everything',
#   'his age',
#   'mid',
#   '80 s',
#   "Hitman's Wife's Bodyguard"],
#  ['Very Bad Design Choices',
#   'the sound',
#   'I',
#   'sound effects',
#   'the rest',
#   'the sound',
#   'It',
#   'the cinema',
#   'it',
#   'the film',
#   'The beginning',
#   'this reason'],
#  ['It',
#   'action comedy crime',
#   'lots',
#   'incredible action',
#   'I',
#   'Audience',
#   'me',
#   'Lots',
#   'talent time',
#   'money',
#   'this production',
#   'I',
#   'all the stars',
#   'I',
#   'a theater',
#   'I',
#   'it',
#   '5 Tuesday',
#   'an Ultra screen IMHO',
#   'a big action picture'],
#  ['what', 'I', 'mins'],
#  ['good fun',
#   'I',
#   'these reviews',
#   'a Samuel Jackson movie',
#   'Sheesh',
#   'a brain'],
#  ['8/ 10 Ratings', '5 Enjoyment', '4 Characters 5 Story'],
#  ['I',
#   'thirty minutes',
#   'I',
#   'it',
#   'The amount',
#   'cringeworthy moments',
#   'The characters',
#   'utterly offensive cartoons',
#   'the story',
#   'no sense',
#   'the dialogue',
#   'every instance',
#   'The acting',
#   'I',
#   'stupider',
#   'the amount',
#   'this film',
#   'I'],
#  ['the top action movie',
#   'the first film',
#   'the sequel',
#   'The story',
#   'comparison',
#   'the original film',
#   'the chemistry',
#   'the main characters',
#   'the hilarious dialogue',
#   'the insane action sequences',
#   'it',
#   'I',
#   'what',
#   'that other reviewer',
#   'regards',
#   'toxic masculinity',
#   'nothing',
#   'it',
#   'the film',
#   'Everything',
#   'this movie',
#   'jest',
#   'a single moment',
#   'I',
#   'toxic masculinity',
#   'your brain',
#   'the ride']]

# %% [markdown]
# ### Check difference in chunking

# %%
difference_in_chunking = [
    item for item in review_chunks if item not in review_chunks_new
]
difference_in_chunking
# Out:
# []

# %% [markdown]
# Output all the chunks in a single list for each review (see above), and submit that output for this assignment.
# Also submit a brief written summary of what you did (describe your selection of genre, your source of reviews,
# how many you collected, and by what means).
#
#  Process:
#    * Using BeautifulSoup
#    * Select genre - this was abitrary
#    * Set genre link
#    * Get list of movies (10) from genre page
#    * Get each movie's respective unique URL
#    * Get a list of reviews from movie page
#    * Get each review's respective unique URL
#    * Filter out reviews > 7 or < 4
#    * Check to see if there are at least 100 reviews
#    * Combine movie title, review title, and review content together
#    * Inspect/review a handful of exmamples
#    * Chunk the reviews into NP using spaCy
#    * Add phrase matches to the corpus
#    * Offset phrase match from word to character for each review
#    * Check the phrase matcher has overlapped any entities, and resolve if so
#    * Format each review using spaCy API, including annotations for named entitities
#    * Train the NER on the corpus with the formatted reviews
#    * Test a couple sentences not in the corpus to see how NER worked
#    * Chunk the reviews again into NP using spaCy after adding NER's to the lexicon
#    * Compare old chunks to new
#
#
#  Surpising to see that the stock NP chunker was the same before and after adding NER's to the lexicon.
#  This speaks to spaCy's chunker, which is statistical in nature.
